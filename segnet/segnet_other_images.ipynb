# %%
# based on https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277/data
#and https://github.com/imlab-uiip/keras-segnet/blob/master/build_model.py

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras import models
from keras.layers.core import Activation, Reshape, Permute
from keras.layers.convolutional import MaxPooling2D, UpSampling2D
from keras.layers.normalization import BatchNormalization
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
n_labels = 1

TRAIN_PATH = '../../PennFudanPed/TRAIN/'
TEST_PATH = '../../PennFudanPed/TEST/'
MASK_PATH  = 'PedMasks/LIP'

IMAGE_PATH = 'PNGImages/LIP'
warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed
# Out:
# Using TensorFlow backend.

# %%
train_img_ids = next(os.walk(TRAIN_PATH + IMAGE_PATH))[2]

train_mask_ids = next(os.walk(TRAIN_PATH + MASK_PATH))[2]

test_img_ids = next(os.walk(TEST_PATH + 'PNGImages'))[2]

# Get and resize train images and masks
X_train = np.zeros((len(train_img_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_img_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_img_ids), total=len(train_img_ids)):
    path = TRAIN_PATH + IMAGE_PATH + "/"
    try:
        img = imread(path+id_)[:,::IMG_CHANNELS]

    except IndexError as e:
        print(e)
        os.remove(path+id_)
    img = np.flip(img, 1)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    
 
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    
    
    
    path = TRAIN_PATH + MASK_PATH + "/"
    mask_ = imread(path+id_[:-4]+'.png')
    
    mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
    mask = np.maximum(mask, mask_)
    #print(np.unique(mask))
    mask = np.where(mask<0.0001, 0, 1)
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 30393/30393 [01:51<00:00, 272.85it/s]

# %%
# Get and resize test images
X_test = np.zeros((len(test_img_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print(len(test_img_ids))
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_img_ids), total=len(test_img_ids)):
    path = TEST_PATH + 'PNGImages' + '/' + id_
    img = imread(path)[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# 16
# Getting and resizing test images ...
# 100%|██████████| 16/16 [00:00<00:00, 141.02it/s]
# Done!

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_img_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
kernel = 3

encoding_layers = [
    Lambda(lambda x: x / 255.0), 
    Conv2D(64, (kernel, kernel), padding='same', input_shape=(IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS) ),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(64, kernel, padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),

    Conv2D(128, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(128, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),

    Conv2D(256, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(256, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(256, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),

    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),

    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),
]

model = models.Sequential()
#model.encoding_layers = encoding_layers

for l in encoding_layers:
    model.add(l)

decoding_layers = [
    UpSampling2D(),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),

    UpSampling2D(),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(512, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(256, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),

    UpSampling2D(),
    Conv2D(256, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(256, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(128, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),

    UpSampling2D(),
    Conv2D(128, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(64, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),

    UpSampling2D(),
    Conv2D(64, (kernel, kernel), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(n_labels, (1, 1), padding='valid'),
    BatchNormalization(),
    Activation('relu')
]
#model.decoding_layers = decoding_layers
for l in decoding_layers:
    model.add(l)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])

# %%
#model.summary()

# %%
from keras.utils import plot_model
plot_model(model, to_file='segnet_model.png')

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('segnet.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=4, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 27353 samples, validate on 3040 samples
# Epoch 1/50
# 27353/27353 [==============================] - 480s 18ms/step - loss: 0.6610 - mean_iou: 0.3191 - val_loss: 0.6242 - val_mean_iou: 0.3393
#
# Epoch 00001: val_loss improved from inf to 0.62416, saving model to segnet.h5
# Epoch 2/50
# 27353/27353 [==============================] - 476s 17ms/step - loss: 0.6244 - mean_iou: 0.3467 - val_loss: 0.6217 - val_mean_iou: 0.3484
#
# Epoch 00002: val_loss improved from 0.62416 to 0.62173, saving model to segnet.h5
# Epoch 3/50
# 27353/27353 [==============================] - 477s 17ms/step - loss: 0.6061 - mean_iou: 0.3514 - val_loss: 0.5931 - val_mean_iou: 0.3560
#
# Epoch 00003: val_loss improved from 0.62173 to 0.59312, saving model to segnet.h5
# Epoch 4/50
# 27353/27353 [==============================] - 483s 18ms/step - loss: 0.5617 - mean_iou: 0.3627 - val_loss: 0.5195 - val_mean_iou: 0.3716
#
# Epoch 00004: val_loss improved from 0.59312 to 0.51948, saving model to segnet.h5
# Epoch 5/50
# 27353/27353 [==============================] - 485s 18ms/step - loss: 0.5161 - mean_iou: 0.3811 - val_loss: 0.4834 - val_mean_iou: 0.3908
#
# Epoch 00005: val_loss improved from 0.51948 to 0.48340, saving model to segnet.h5
# Epoch 6/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.4821 - mean_iou: 0.3999 - val_loss: 0.4740 - val_mean_iou: 0.4087
#
# Epoch 00006: val_loss improved from 0.48340 to 0.47402, saving model to segnet.h5
# Epoch 7/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.4582 - mean_iou: 0.4167 - val_loss: 0.4386 - val_mean_iou: 0.4247
#
# Epoch 00007: val_loss improved from 0.47402 to 0.43863, saving model to segnet.h5
# Epoch 8/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.4399 - mean_iou: 0.4321 - val_loss: 0.4315 - val_mean_iou: 0.4391
#
# Epoch 00008: val_loss improved from 0.43863 to 0.43149, saving model to segnet.h5
# Epoch 9/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.4331 - mean_iou: 0.4452 - val_loss: 0.4201 - val_mean_iou: 0.4512
#
# Epoch 00009: val_loss improved from 0.43149 to 0.42014, saving model to segnet.h5
# Epoch 10/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.4125 - mean_iou: 0.4572 - val_loss: 0.4198 - val_mean_iou: 0.4626
#
# Epoch 00010: val_loss improved from 0.42014 to 0.41982, saving model to segnet.h5
# Epoch 11/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.4000 - mean_iou: 0.4678 - val_loss: 0.4120 - val_mean_iou: 0.4729
#
# Epoch 00011: val_loss improved from 0.41982 to 0.41201, saving model to segnet.h5
# Epoch 12/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.3966 - mean_iou: 0.4778 - val_loss: 0.4039 - val_mean_iou: 0.4821
#
# Epoch 00012: val_loss improved from 0.41201 to 0.40393, saving model to segnet.h5
# Epoch 13/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.3753 - mean_iou: 0.4868 - val_loss: 0.4050 - val_mean_iou: 0.4912
#
# Epoch 00013: val_loss did not improve from 0.40393
# Epoch 14/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.3672 - mean_iou: 0.4955 - val_loss: 0.3989 - val_mean_iou: 0.4995
#
# Epoch 00014: val_loss improved from 0.40393 to 0.39888, saving model to segnet.h5
# Epoch 15/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.3581 - mean_iou: 0.5036 - val_loss: 0.3979 - val_mean_iou: 0.5074
#
# Epoch 00015: val_loss improved from 0.39888 to 0.39792, saving model to segnet.h5
# Epoch 16/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.3411 - mean_iou: 0.5115 - val_loss: 0.4260 - val_mean_iou: 0.5152
#
# Epoch 00016: val_loss did not improve from 0.39792
# Epoch 17/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.3331 - mean_iou: 0.5187 - val_loss: 0.4117 - val_mean_iou: 0.5225
#
# Epoch 00017: val_loss did not improve from 0.39792
# Epoch 18/50
# 27353/27353 [==============================] - 486s 18ms/step - loss: 0.3189 - mean_iou: 0.5264 - val_loss: 0.4134 - val_mean_iou: 0.5300
#
# Epoch 00018: val_loss did not improve from 0.39792
# Epoch 19/50
# 27353/27353 [==============================] - 479s 18ms/step - loss: 0.3167 - mean_iou: 0.5336 - val_loss: 0.4068 - val_mean_iou: 0.5370
#
# Epoch 00019: val_loss did not improve from 0.39792
# Epoch 20/50
# 27353/27353 [==============================] - 480s 18ms/step - loss: 0.2971 - mean_iou: 0.5407 - val_loss: 0.5045 - val_mean_iou: 0.5441
#
# Epoch 00020: val_loss did not improve from 0.39792
# Epoch 00020: early stopping

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      1792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_2 (Activation)    (None, 128, 128, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 512)       1180160
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_14 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_17 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 16, 256)       1179904
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_21 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 32, 32, 128)       295040
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_22 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_23 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_24 (Activation)   (None, 64, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_25 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 128, 128, 1)       65
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 128, 128, 1)       4
# _________________________________________________________________
# activation_26 (Activation)   (None, 128, 128, 1)       0
# =================================================================
# Total params: 29,458,949
# Trainable params: 29,443,075
# Non-trainable params: 15,874
# _________________________________________________________________

# %%
# Predict on train, val and test
model = load_model('segnet.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 27353/27353 [==============================] - 60s 2ms/step
# 3040/3040 [==============================] - 6s 2ms/step
# 16/16 [==============================] - 0s 19ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
print(len(preds_test_t))
ix = random.randint(0, len(preds_test_t))
print(X_train.shape[0])
print(X_test.shape[0])
print(int(X_test.shape[0]*0.9))
print(ix)
imshow(X_test[ix])
plt.show()
imshow(np.squeeze(preds_test_t[ix]))
plt.show()
# Out:
# 16
# 30393
# 16
# 14
# 14
